# %%
import numpy as np
import matplotlib
matplotlib.use('nbagg')
import matplotlib.pyplot as plt

from pyhacores.filter.fir.model import FIR
from pyhacores.quadrature_demodulator.model import QuadratureDemodulator
from scipy import signal
from pyha.common.util import plot_freqz

# %%
y = np.load('data/taranis_sps16_fs1600000.0_band1000000.0_far_onepackage_filter0.1.npy')


plt.plot(abs(y))
plt.show()


demod = QuadratureDemodulator()
y = demod.model_main(y)

plt.plot(y)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="967">
